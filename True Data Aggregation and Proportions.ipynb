# %%
  import pandas as pd
  from openpyxl import load_workbook
  import os
  from zipfile import BadZipFile  # Import the error class

  # USA SECTORS MAPPING
  category_mapping = {
      'Agriculture': [
          'Agriculture, forestry, fishing and hunting',
      ],
      'Industry': [
          'Mining, quarrying, and oil and gas extraction',
          'Utilities',
          'Construction',
          'Manufacturing',
      ],
      'Services': [
          'Trade',
          'Information',
          'Transportation and warehousing',
          'Finance, insurance, real estate, rental, and leasing',
          'Professional and business services',
          'Educational services, health care, and social assistance',
          'Arts, entertainment, recreation, accommodation, and food services',
          'Government and government enterprises',
          'Other services (except government and government enterprises)'
      ]
  }

  # Function to classify sectors
  def classify_sector(description):
      for category, keywords in category_mapping.items():
          for keyword in keywords:
              if keyword in description:
                  return category
      return None  # Return None if no category is matched

  # Path to the input directory
  input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

  # Iterate through files in the input directory
  for filename in os.listdir(input_directory):
      if 'Usa' in filename and filename.endswith('.xlsx'):
          input_file_path = os.path.join(input_directory, filename)

          try:
              # Try to read the Excel file
              df = pd.read_excel(input_file_path, engine='openpyxl')

              # Ensure the DataFrame contains the expected columns
              if 'Description' in df.columns and 'GDP' in df.columns:
                  # Convert the GDP column to numeric, coerce errors to NaN
                  df['GDP'] = pd.to_numeric(df['GDP'], errors='coerce')

                  # Initialize a dictionary for aggregating GDP by category
                  aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

                  # Process each row
                  for _, row in df.iterrows():
                      description = row['Description']
                      gdp = row['GDP']
                      category = classify_sector(description)

                      # If a category was found and GDP is not NaN, add the GDP to the respective category
                      if category and not pd.isna(gdp):
                          aggregation[category] += gdp

                  # Prepare the final DataFrame
                  final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

                  # Calculate the total GDP
                  total_gdp = final_df['Aggregated GDP'].sum()

                  # Create a DataFrame for the total row
                  total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

                  # Concatenate the total row to the final DataFrame
                  final_df = pd.concat([final_df, total_row], ignore_index=True)

                  # Calculate the proportion of total GDP for each category
                  final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

                  # Load the existing workbook to check for the existing sheet
                  workbook = load_workbook(input_file_path)

                  # Check if the sheet already exists
                  if 'Aggregated GDP' in workbook.sheetnames:
                      # Remove the existing sheet
                      del workbook['Aggregated GDP']

                  # Write the results to a new tab in the original Excel file
                  with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                      final_df.to_excel(writer, sheet_name='Aggregated Data', index=False)

                  print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
              else:
                  print(f"Error: The required columns 'Description' and 'GDP' are not present in the file {filename}.")

          except BadZipFile:
              print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
          except Exception as e:
              print(f"Skipped file {filename}: An error occurred: {e}")
# Out:
# Aggregation complete for Elbert Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mason Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Chicot Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Marin Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Amherst Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Moffat Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hawaii Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Iberville Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Amite Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Harrison Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Montrose Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wright Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Upson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kimball Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Musselshell Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cheshire Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sutter Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Crawford Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dickenson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Claiborne Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Clayton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Iberia Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ziebach Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sully Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Monongalia Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mingo Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Shenandoah Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Huron Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Leflore Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Butte Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sequoyah Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Klamath Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Powell Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bryan Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lafourche Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hopkins Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cayuga Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Henderson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bergen Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Passaic Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Richland Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Nez Perce Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hertford Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Licking Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mellette Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Oglala Lakota Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wheeler Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Roseau Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Clarke Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wilcox Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Blair Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Emmet Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Goshen Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hale Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Summers Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Blaine Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Outagamie Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Douglas Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Terrebonne Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sonoma Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Custer Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sherburne Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bates Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Harney Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Forest Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Buchanan Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Walker Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Labette Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Chenango Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Oconto Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Milwaukee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Providence Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Juneau Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Vilas Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kodiak Island Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Iosco Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Washburn Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Humboldt Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pickaway Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Teton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cheboygan Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Garrard Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Freestone Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Amelia Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Baldwin Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Stokes Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bonneville Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Desoto Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Walworth Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Fremont Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Foard Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Burke Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kenedy Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Candler Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gwinnett Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Burnet Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jones Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Glascock Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lowndes Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Levy Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Concordia Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Colleton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Norfolk Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wheatland Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sebastian Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Creek Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Langlade Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jeff Davis Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Coosa Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Glades Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hinds Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Auglaize Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gordon Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wibaux Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Seward Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Larue Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gallia Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Thurston Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mississippi Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hill Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Houston Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mora Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Scotts Bluff Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Champaign Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for James City Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Laurel Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sacramento Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Del Norte Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Goodhue Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rapides Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Yuba Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dekalb Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Attala Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pope Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Prince Of Wales Hyder Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Boulder Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ste Genevieve Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Matanuska Susitna Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Valdez Cordova Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hoonah Angoon Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for St Lucie Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Yukon Koyukuk Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Clark Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Chippewa Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Miami Dade Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Baxter Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mitchell Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Miller Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hardy Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Scott Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Chambers Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Talbot Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Marshall Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Coffee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Simpson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Banner Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wood Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Drew Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gibson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Grainger Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Barbour Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Weber Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Taylor Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mercer Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Eaton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Henry Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Norton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Nolan Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Elk Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gage Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Coleman Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mcleod Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Coke Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Swift Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Archer Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Becker Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Maverick Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pendleton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mcintosh Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ashley Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Carver Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Converse Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Smith Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Saunders Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mcdonald Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Quay Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gregory Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Armstrong Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Callaway Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Stark Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cooper Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cambria Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gates Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ford Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mccormick Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dodge Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Garrett Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Woods Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lewis Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Chase Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tucker Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Solano Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ness Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Churchill Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Menard Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Carter Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Avery Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Stanley Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for George Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sharp Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Alpine Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kerr Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sanders Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Spalding Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Concho Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Keith Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Fisher Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Crane Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Otoe Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Russell Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rusk Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rush Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Oglethorpe Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Johnston Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cochise Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Allegan Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hickory Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Warrick Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tate Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Osage Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tioga Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Grand Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Greeley Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Washtenaw Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lander Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pitt Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Salt Lake Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Snyder Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Elmore Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pierce Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dupage Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tooele Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Escambia Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Greenbrier Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Alfalfa Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lares Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Northumberland Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Van Buren Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Walthall Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Frederick Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Quitman Usa.xlsx and saved to a new tab in the Excel file.
# Skipped file Daggett Usa.xlsx: File is not a valid zip (Excel) file.
# Aggregation complete for Wichita Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Washita Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ouachita Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kittitas Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Klickitat Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Itawamba Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Butler Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Genesee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dooly Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Yuma Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Okaloosa Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Fannin Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Madera Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Etowah Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Costilla Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wake Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Albany Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Arapahoe Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lucas Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sandoval Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Brevard Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Culpeper Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Columbiana Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Henrico Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lac Qui Parle Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lipscomb Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sublette Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tolland Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sanpete Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Huerfano Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tippah Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Clearfield Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tensas Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Glenn Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Idaho Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pinellas Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Charlton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cibola Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bond Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Trigg Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Berkeley Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Muhlenberg Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pender Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Deer Lodge Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Moniteau Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ray Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sedgwick Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Chautauqua Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Granite Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Stanton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Crow Wing Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gaston Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dutchess Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kay Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Winnebago Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Allamakee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Durham Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Vinton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Boyd Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cocke Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Roosevelt Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pearl River Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Natchitoches Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rich Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lorain Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Burleigh Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kittson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Atlantic Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cheyenne Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Brooke Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Waldo Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Valencia Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Onslow Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Herkimer Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cecil Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sagadahoc Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ralls Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jersey Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Nance Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hamblen Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wilbarger Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for District Of Columbia Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dillingham Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Allegheny Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bowie Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Brewster Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Habersham Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Abbeville Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cobb Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Siskiyou Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Muscogee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Owsley Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Fairfax Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dyer Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Stoddard Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Breckinridge Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hoke Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dubuque Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Matagorda Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Stillwater Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sequatchie Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Florence Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wyandotte Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Uintah Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mccreary Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hocking Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tarrant Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kleberg Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rosebud Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hamilton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Barrow Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Daviess Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Litchfield Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Judith Basin Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Beauregard Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Marlboro Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rockbridge Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Greensville Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Appling Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Power Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Limestone Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Meagher Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gooding Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Muskogee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Macomb Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Atoka Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kearny Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Glasscock Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gogebic Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jessamine Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Copiah Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Guthrie Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bertie Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Barren Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Yakima Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Spokane Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Craig Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lenawee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hodgeman Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mackinac Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Duval Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gilchrist Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Clare Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wabasha Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sherman Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Craven Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Montmorency Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Arenac Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Midland Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Brookings Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Osborne Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Aurora Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dickson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Spink Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Major Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bandera Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Skagway Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Baylor Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hand Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Berkshire Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Buckingham Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Price Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Niobrara Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Thayer Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Fluvanna Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Minnehaha Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pipestone Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mower Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Box Butte Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hendricks Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Starke Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hooker Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bollinger Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kimble Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lavaca Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Harper Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Meeker Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Geauga Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Twiggs Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Watonwan Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Okmulgee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bremer Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Schleicher Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Nowata Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hettinger Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Comanche Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rawlins Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Southeast Fairbanks Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Eau Claire Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tama Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Beckham Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Codington Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Alcorn Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Greenville Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jerauld Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pettis Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for North Slope Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Flathead Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Minidoka Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Karnes Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Stutsman Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Erath Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Broadwater Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jim Wells Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gray Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Catron Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Aroostook Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Estill Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lyman Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Crisp Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cavalier Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bottineau Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tallapoosa Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kusilvak Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Leake Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Allegany Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Western Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Neshoba Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kearney Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Holmes Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Grenada Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bamberg Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Christian Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Thomas Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Oktibbeha Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Alamosa Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ogle Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Faulk Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Northwest Arctic Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Otter Tail Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Coconino Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kingman Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Terry Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Valley Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Randall Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tuscarawas Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Guernsey Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tippecanoe Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Upton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sterling Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pueblo Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jenkins Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Garza Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Stonewall Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Winkler Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gregg Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Schenectady Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Titus Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pontotoc Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hutchinson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Athens Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lemhi Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Early Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Forrest Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pushmataha Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Young Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Noxubee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Aitkin Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wagoner Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sitka Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Beaverhead Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Grundy Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Iowa Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ransom Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dunn Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Faribault Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kalkaska Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hartley Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mcmullen Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sargent Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Coshocton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kossuth Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Trego Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Zapata Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mchenry Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Motley Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mayes Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sunflower Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tom Green Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Roger Mills Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Amador Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pocahontas Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kaufman Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Denver Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cullman Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Otero Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lonoke Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Colquitt Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Eastland Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tallahatchie Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Morehouse Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Oconee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mckenzie Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Shawnee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Moody Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Muscatine Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bear Lake Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Perry Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Westchester Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pasquotank Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Des Moines Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Apache Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tangipahoa Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for York Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cooke Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Reynolds Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kings Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Randolph Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hickman Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mendocino Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hernando Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dent Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wayne Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Buffalo Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Fulton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Clackamas Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Love Usa.xlsx and saved to a new tab in the Excel file.
# ...
# Aggregation complete for Sawyer Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Vermillion Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Crook Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Treasure Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Acadia Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Glacier Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Merrick Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jennings Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Fleming Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Yates Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Eureka Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Howell Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Calaveras Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Coweta Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mariposa Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Trumbull Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Coos Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Placer Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Anchorage Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Preble Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Williamson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wyandot Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Malheur Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bullitt Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Canyon Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Haywood Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gentry Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Evangeline Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Colorado Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cottonwood Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sharkey Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kershaw Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Turner Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Somerset Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Phelps Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for King and Queen Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dukes Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Switzerland Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Charles Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Greenlee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Navajo Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for New Castle Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Inyo Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Catahoula Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Morton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Nemaha Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Merced Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Trinity Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hot Spring Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bayfield Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Winston Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pemiscot Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Keya Paha Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Chisago Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Toole Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Andrew Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Aransas Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Oswego Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Windsor Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mahoning Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Fallon Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Crosby Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Calumet Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Milam Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Willacy Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Presidio Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wharton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Todd Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Juniata Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Yavapai Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tillamook Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Chemung Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Los Angeles Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Forsyth Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Knott Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mcdonough Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wilkinson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ware Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wirt Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dolores Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Loup Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Robeson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Nevada Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pointe Coupee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Redwood Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Clearwater Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Trimble Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Washoe Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Washakie Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Baraga Usa.xlsx and saved to a new tab in the Excel file.
# Skipped file Latah Usa.xlsx: File is not a valid zip (Excel) file.
# Aggregation complete for Autauga Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Beaver Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pottawatomie Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Leslie Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Clinton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Denali Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Choctaw Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lyon Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Humphreys Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Crowley Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hudson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Yazoo Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Columbus Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gunnison Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lamoille Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Chilton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Guadalupe Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kent Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Strafford Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cook Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tazewell Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Darke Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sevier Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mille Lacs Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Indiana Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cumberland Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ascension Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wilkes Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Whiteside Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wasatch Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tillman Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cherokee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Camp Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ben Hill Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Newport Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Harford Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Whitman Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bossier Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gem Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Walsh Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sullivan Usa.xlsx and saved to a new tab in the Excel file.
# Error: The required columns 'Description' and 'GDP' are not present in the file New York Usa.xlsx.
# Aggregation complete for Skamania Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Yellow Medicine Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Larimer Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bailey Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tuscola Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Walton Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Emmons Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Asotin Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dinwiddie Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hawkins Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dade Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dougherty Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Clay Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jackson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bennington Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Corson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Doddridge Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Chattahoochee Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Toombs Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Yellowstone Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Stearns Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rockcastle Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rockland Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ida Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kenai Peninsula Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Fort Bend Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Finney Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Nicholas Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Montgomery Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Scotland Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sabine Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dorado Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Highland Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Onondaga Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Laclede Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wetzel Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Camden Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pittsylvania Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lake Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cattaraugus Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Centre Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Carteret Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bexar Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Carson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Benson Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Piatt Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Spencer Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Atchison Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Walla Walla Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dakota Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Slope Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rice Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Itasca Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lumpkin Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Fayette Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pecos Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Breathitt Usa.xlsx and saved to a new tab in the Excel file.

# %%
import pandas as pd
from openpyxl import load_workbook
import os
from zipfile import BadZipFile  # Import the error class

# BRAZIL SECTORS MAPPING
category_mapping = {
    'Agriculture': [
        'Agriculture, including support for agriculture and post-harvest activities',
        'Livestock, including support for livestock',
        'Forestry, fishing, and aquaculture'
    ],
    'Industry': [
        'Extractive industries',
        'Manufacturing industries',
        'Electricity, gas, water, sewage, waste management, and remediation activities',
        'Construction'
    ],
    'Services': [
        'Wholesale and retail trade; repair of motor vehicles and motorcycles',
        'Transportation, storage, and postal services',
        'Accommodation and food services',
        'Information and communication',
        'Financial and insurance activities and related services',
        'Real estate activities',
        'Professional, scientific, and technical activities; administrative and support services',
        'Public administration, defense, education, and public health and social security',
        'Private education and health services',
        'Arts, culture, sports, and recreation and other service activities',
        'Domestic services'
    ]
}

# Function to classify sectors
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None  # Return None if no category is matched

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    # Check if "Bra" or "BRA" exists as a standalone term in the filename (case-insensitive)
    if 'bra' in filename.lower().split() and filename.endswith('.xlsx'):
        input_file_path = os.path.join(input_directory, filename)

        try:
            # Try to read the Excel file
            df = pd.read_excel(input_file_path, engine='openpyxl')

            # Ensure the DataFrame contains the expected columns
            if df.columns[0] == 'Description' and df.columns[1] == 'GDP':
                # Convert the GDP column to numeric, coerce errors to NaN
                df['GDP'] = pd.to_numeric(df['GDP'], errors='coerce')

                # Initialize a dictionary for aggregating GDP by category
                aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

                # Process each row
                for _, row in df.iterrows():
                    description = row['Description']
                    gdp = row['GDP']
                    category = classify_sector(description)

                    # If a category was found and GDP is not NaN, add the GDP to the respective category
                    if category and not pd.isna(gdp):
                        aggregation[category] += gdp

                # Prepare the final DataFrame
                final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

                # Calculate the total GDP
                total_gdp = final_df['Aggregated GDP'].sum()

                # Create a DataFrame for the total row
                total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

                # Concatenate the total row to the final DataFrame
                final_df = pd.concat([final_df, total_row], ignore_index=True)

                # Calculate the proportion of total GDP for each category
                final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

                # Load the existing workbook to check for the existing sheet
                workbook = load_workbook(input_file_path)

                # Check if the sheet already exists
                if 'Aggregated GDP' in workbook.sheetnames:
                    # Remove the existing sheet
                    del workbook['Aggregated GDP']

                # Write the results to a new tab in the original Excel file
                with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                    final_df.to_excel(writer, sheet_name='Aggregated Data', index=False)

                print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
            else:
                print(f"Error: The required columns 'Description' and 'GDP' are not present in the file {filename}.")

        except BadZipFile:
            print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
        except Exception as e:
            print(f"Skipped file {filename}: An error occurred: {e}")

# %%
import pandas as pd
from openpyxl import load_workbook
import os
from zipfile import BadZipFile  # Import the error class
import re  # Import the regex module

# BRAZIL SECTORS MAPPING
category_mapping = {
    'Agriculture': [
        'Agriculture, including support for agriculture and post-harvest activities',
        'Livestock, including support for livestock',
        'Forestry, fishing, and aquaculture'
    ],
    'Industry': [
        'Extractive industries',
        'Manufacturing industries',
        'Electricity, gas, water, sewage, waste management, and remediation activities',
        'Construction'
    ],
    'Services': [
        'Wholesale and retail trade; repair of motor vehicles and motorcycles',
        'Transportation, storage, and postal services',
        'Accommodation and food services',
        'Information and communication',
        'Financial and insurance activities and related services',
        'Real estate activities',
        'Professional, scientific, and technical activities; administrative and support services',
        'Public administration, defense, education, and public health and social security',
        'Private education and health services',
        'Arts, culture, sports, and recreation and other service activities',
        'Domestic services'
    ]
}

# Function to classify sectors
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None  # Return None if no category is matched

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    # Use regex to match "Bra" or "BRA" as a standalone term in the filename
    if re.search(r'\b[Bb][Rr][Aa]\b', filename) and filename.endswith('.xlsx'):
        input_file_path = os.path.join(input_directory, filename)

        try:
            # Try to read the Excel file
            df = pd.read_excel(input_file_path, engine='openpyxl')

            # Ensure the DataFrame contains the expected columns
            if df.columns[0] == 'Sector' and df.columns[1] == 'Units':
                # Convert the GDP column to numeric, coerce errors to NaN
                df['Units'] = pd.to_numeric(df['Units'], errors='coerce')

                # Initialize a dictionary for aggregating GDP by category
                aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

                # Process each row
                for _, row in df.iterrows():
                    description = row['Sector']
                    gdp = row['Units']
                    category = classify_sector(description)

                    # If a category was found and GDP is not NaN, add the GDP to the respective category
                    if category and not pd.isna(gdp):
                        aggregation[category] += gdp

                # Prepare the final DataFrame
                final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

                # Calculate the total GDP
                total_gdp = final_df['Aggregated GDP'].sum()

                # Create a DataFrame for the total row
                total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

                # Concatenate the total row to the final DataFrame
                final_df = pd.concat([final_df, total_row], ignore_index=True)

                # Calculate the proportion of total GDP for each category
                final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

                # Load the existing workbook to check for the existing sheet
                workbook = load_workbook(input_file_path)

                # Check if the sheet already exists
                if 'Aggregated GDP' in workbook.sheetnames:
                    # Remove the existing sheet
                    del workbook['Aggregated GDP']

                # Write the results to a new tab in the original Excel file
                with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                    final_df.to_excel(writer, sheet_name='Aggregated Data', index=False)

                print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
            else:
                print(f"Error: The required columns 'Description' and 'GDP' are not present in the file {filename}.")

        except BadZipFile:
            print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
        except Exception as e:
            print(f"Skipped file {filename}: An error occurred: {e}")
# Out:
# Error: The required columns 'Description' and 'GDP' are not present in the file Baiao Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Virginia Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Seara Bra.xlsx.
# Aggregation complete for Sonora Bra.xlsx and saved to a new tab in the Excel file.
# Error: The required columns 'Description' and 'GDP' are not present in the file Rondon Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Distrito Federal BRA.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Rio Do Oeste Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Parnaiba Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Minas Gerais BRA.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Parana Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Espirito Santo Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Normandia Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Amapa Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Porto Acre Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Parau Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Alagoa Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Maraa Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Monte Alegre De Sergipe Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Cambuci Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Sao Paulo Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Picui Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Porto Amazonas Bra.xlsx.
# Aggregation complete for California Bra.xlsx and saved to a new tab in the Excel file.
# Error: The required columns 'Description' and 'GDP' are not present in the file Mimoso Do Sul Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Cerro Grande Do Sul Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Rio Grande Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file North Region BRA.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Brasilia Bra.xlsx.
# Error: The required columns 'Description' and 'GDP' are not present in the file Goias Bra.xlsx.

# %%
import pandas as pd
from openpyxl import load_workbook
import os
from zipfile import BadZipFile
import re

# Updated NORWAY SECTORS MAPPING with new sectors added
category_mapping = {
    'Agriculture': [
        'Agriculture and forestry',
        'Fishing and aquaculture',
        'Agriculture, including support for agriculture and post-harvest activities',
        'Livestock, including support for livestock',
        'Forestry, fishing, and aquaculture'
    ],
    'Industry': [
        'Service activities incidental to oil and gas',
        'Manufacturing',
        'Food products, beverages and tobacco',
        'Textiles, wearing apparel, leather',
        'Wood, wood products and paper products',
        'Printing and reproduction of recorded media',
        'Refined petroleum, chemical and pharmaceutical products',
        'Rubber, plastic and mineral products',
        'Basic metals',
        'Machinery and other equipment n.e.c',
        'Building of ships, oil platforms and moduls and other transport equipment',
        'Water supply, sewerage, waste',
        'Construction',
        'Extractive industries',
        'Mining and quarrying',
        'Oil and gas extraction including services',
        'Oil and gas extraction',
        'Electricity, gas and steam'
    ],
    'Services': [
        'Wholesale and retail trade, repair of motor vehicles',
        'Transport via pipelines',
        'Ocean transport',
        'Transport activities excl. ocean transport',
        'Postal and courier activities',
        'Accommodation and food service activities',
        'Information and communication',
        'Financial and insurance activities',
        'Real estate activities',
        'Imputed rents of owner-occupied dwellings',
        'Professional, scientific and and technical activities',
        'Administrative and support service activities',
        'Public administration and defence',
        'Education',
        'Health and social work',
        'Arts, entertainment and other service activities',
        'Transportation, storage, and postal services',
        'Accommodation and food services',
        'Public administration, defense, education, and public health and social security',
        'Private education and health services',
        'Arts, culture, sports, and recreation and other service activities',
        'Domestic services'
    ]
}

# Function to classify sectors
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    # Use regex to match "Nor" or "NOR" as a standalone term in the filename
    if re.search(r'\b[Nn][Oo][Rr]\b', filename) and filename.endswith('.xlsx'):
        input_file_path = os.path.join(input_directory, filename)

        try:
            # Read the Excel file without headers, starting directly at row 2
            df = pd.read_excel(input_file_path, engine='openpyxl', header=None, skiprows=1)

            # Inspect the shape of the dataframe to understand its structure
            print(f"File: {filename} - Shape of DataFrame: {df.shape}")

            # Ensure we only select the first two columns
            df = df.iloc[:, [0, 1]]  # Select the first two columns (Sector and Units)

            # Rename columns to 'Sector' and 'Units' for easier access
            df.columns = ['Sector', 'Units']

            # Convert the Units column to numeric, coerce errors to NaN
            df['Units'] = pd.to_numeric(df['Units'], errors='coerce')

            # Initialize a dictionary for aggregating GDP by category
            aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

            # Process each row
            for _, row in df.iterrows():
                description = row['Sector']
                gdp = row['Units']
                category = classify_sector(description)

                # If a category was found and GDP is not NaN, add the GDP to the respective category
                if category and not pd.isna(gdp):
                    aggregation[category] += gdp

            # Prepare the final DataFrame
            final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

            # Calculate the total GDP
            total_gdp = final_df['Aggregated GDP'].sum()

            # Create a DataFrame for the total row
            total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

            # Concatenate the total row to the final DataFrame
            final_df = pd.concat([final_df, total_row], ignore_index=True)

            # Calculate the proportion of total GDP for each category
            final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

            # Load the existing workbook to check for the existing sheet
            workbook = load_workbook(input_file_path)

            # Check if the sheet already exists
            if 'Aggregated GDP' in workbook.sheetnames:
                # Remove the existing sheet
                del workbook['Aggregated GDP']

            # Write the results to a new tab in the original Excel file
            with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                final_df.to_excel(writer, sheet_name='Aggregated Data', index=False)

            print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
        except BadZipFile:
            print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
        except Exception as e:
            print(f"Skipped file {filename}: An error occurred: {e}")
# Out:
# File: Svalbard NOR.xlsx - Shape of DataFrame: (41, 19)
# Aggregation complete for Svalbard NOR.xlsx and saved to a new tab in the Excel file.
# File: Vestfold og Telemark NOR.xlsx - Shape of DataFrame: (33, 19)
# Aggregation complete for Vestfold og Telemark NOR.xlsx and saved to a new tab in the Excel file.
# File: Froland Nor Nor.xlsx - Shape of DataFrame: (41, 19)
# Aggregation complete for Froland Nor Nor.xlsx and saved to a new tab in the Excel file.
# File: Møre og Romsdal NOR.xlsx - Shape of DataFrame: (41, 19)
# Aggregation complete for Møre og Romsdal NOR.xlsx and saved to a new tab in the Excel file.
# File: Iveland Nor Nor.xlsx - Shape of DataFrame: (41, 19)
# Aggregation complete for Iveland Nor Nor.xlsx and saved to a new tab in the Excel file.
# File: Oslo Nor Nor.xlsx - Shape of DataFrame: (36, 19)
# Aggregation complete for Oslo Nor Nor.xlsx and saved to a new tab in the Excel file.
# File: Agder NOR.xlsx - Shape of DataFrame: (38, 19)
# Aggregation complete for Agder NOR.xlsx and saved to a new tab in the Excel file.
# File: Innlandet NOR.xlsx - Shape of DataFrame: (31, 19)
# Aggregation complete for Innlandet NOR.xlsx and saved to a new tab in the Excel file.
# File: The Continental Shelf NOR.xlsx - Shape of DataFrame: (41, 19)
# Aggregation complete for The Continental Shelf NOR.xlsx and saved to a new tab in the Excel file.
# File: Vikna Nor Nor.xlsx - Shape of DataFrame: (36, 19)
# Aggregation complete for Vikna Nor Nor.xlsx and saved to a new tab in the Excel file.

# %%
#Germany

import pandas as pd
from openpyxl import load_workbook
import os
from zipfile import BadZipFile
import re

# Updated sector mappings with new categories for Agriculture, Industry, Services
category_mapping = {
    'Agriculture': [
        'Agriculture, forestry & fishing'
    ],
    'Industry': [
        'Industry',
        'Mining & quarrying',
        'Manufacturing',
        'Construction',
        'Electricity, water, waste'
    ],
    'Services': [
        'Trade, transportation, food',
        'Real estate',
        'Public administration',
        'Health & social work',
        'Administrative & support',
        'Education',
        'Information, communication, finance',
        'Other services',
        'Professional, scientific & technical'
    ]
}

# Function to classify sectors based on the updated mapping
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    # Use regex to match "NOR" or "DEU" in the filename
    if re.search(r'\b(DEU|Deu)\b', filename) and filename.endswith('.xlsx'):
        input_file_path = os.path.join(input_directory, filename)

        try:
            # Read the Excel file without headers, starting directly at row 2
            df = pd.read_excel(input_file_path, engine='openpyxl', header=None, skiprows=1)

            # Print the shape of the dataframe for debugging purposes
            print(f"File: {filename} - Shape of DataFrame: {df.shape}")

            # Ensure we only select the first two columns
            df = df.iloc[:, [0, 1]]  # Select the first two columns (Sector and Units)

            # Rename columns to 'Sector' and 'Units' for easier access
            df.columns = ['Sector', 'Units']

            # Convert the Units column to numeric, coerce errors to NaN
            df['Units'] = pd.to_numeric(df['Units'], errors='coerce')

            # Initialize a dictionary for aggregating GDP by category
            aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

            # Process each row
            for _, row in df.iterrows():
                description = row['Sector']
                gdp = row['Units']
                category = classify_sector(description)

                # If a category was found and GDP is not NaN, add the GDP to the respective category
                if category and not pd.isna(gdp):
                    aggregation[category] += gdp

            # Prepare the final DataFrame
            final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

            # Calculate the total GDP
            total_gdp = final_df['Aggregated GDP'].sum()

            # Create a DataFrame for the total row
            total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

            # Concatenate the total row to the final DataFrame
            final_df = pd.concat([final_df, total_row], ignore_index=True)

            # Calculate the proportion of total GDP for each category
            final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

            # Load the existing workbook to check for the existing sheet
            workbook = load_workbook(input_file_path)

            # Check if the sheet already exists
            if 'Aggregated Data' in workbook.sheetnames:
                # Remove the existing sheet
                del workbook['Aggregated Data']

            # Write the results to a new tab in the original Excel file
            with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                # Write the DataFrame starting from cell A2
                final_df.to_excel(writer, sheet_name='Aggregated Data', index=False, startrow=1)

            print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
        except BadZipFile:
            print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
        except Exception as e:
            print(f"Skipped file {filename}: An error occurred: {e}")
# Out:
# File: Saarland Deu.xlsx - Shape of DataFrame: (8, 19)
# Skipped file Saarland Deu.xlsx: An error occurred: Sheet 'Aggregated Data' already exists and if_sheet_exists is set to 'error'.
# File: Hamburg Deu.xlsx - Shape of DataFrame: (18, 19)
# Skipped file Hamburg Deu.xlsx: An error occurred: argument of type 'float' is not iterable
# File: Brandenburg Deu.xlsx - Shape of DataFrame: (14, 19)
# Aggregation complete for Brandenburg Deu.xlsx and saved to a new tab in the Excel file.
# File: Sachsen Anhalt Deu.xlsx - Shape of DataFrame: (11, 19)
# Skipped file Sachsen Anhalt Deu.xlsx: An error occurred: argument of type 'float' is not iterable
# File: Saxony-Anhalt DEU.xlsx - Shape of DataFrame: (17, 18)
# Skipped file Saxony-Anhalt DEU.xlsx: An error occurred: argument of type 'float' is not iterable
# File: North Rhine-Westphalia DEU.xlsx - Shape of DataFrame: (16, 18)
# Aggregation complete for North Rhine-Westphalia DEU.xlsx and saved to a new tab in the Excel file.
# File: Berlin Slv DEU.xlsx - Shape of DataFrame: (17, 18)
# Skipped file Berlin Slv DEU.xlsx: An error occurred: argument of type 'float' is not iterable
# File: Bavaria (Bayern) DEU.xlsx - Shape of DataFrame: (14, 18)
# Skipped file Bavaria (Bayern) DEU.xlsx: An error occurred: argument of type 'float' is not iterable
# File: Rhineland-Palatinate DEU.xlsx - Shape of DataFrame: (7, 18)
# Aggregation complete for Rhineland-Palatinate DEU.xlsx and saved to a new tab in the Excel file.
# File: Bremen DEU.xlsx - Shape of DataFrame: (10, 18)
# Skipped file Bremen DEU.xlsx: An error occurred: argument of type 'float' is not iterable
# <ipython-input-2-52919bbd5c4e>:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Units'] = pd.to_numeric(df['Units'], errors='coerce')
# File: Hessen DEU.xlsx - Shape of DataFrame: (21, 18)
# Skipped file Hessen DEU.xlsx: An error occurred: argument of type 'float' is not iterable
# File: Saxony DEU.xlsx - Shape of DataFrame: (7, 18)
# Aggregation complete for Saxony DEU.xlsx and saved to a new tab in the Excel file.
# File: Lower Saxony DEU.xlsx - Shape of DataFrame: (16, 18)
# Aggregation complete for Lower Saxony DEU.xlsx and saved to a new tab in the Excel file.
# File: Schleswig Holstein Deu.xlsx - Shape of DataFrame: (11, 19)
# Aggregation complete for Schleswig Holstein Deu.xlsx and saved to a new tab in the Excel file.
# File: Mecklenburg-Western DEU.xlsx - Shape of DataFrame: (21, 18)
# Skipped file Mecklenburg-Western DEU.xlsx: An error occurred: argument of type 'float' is not iterable
# File: Mecklenburg Vorpommern Deu.xlsx - Shape of DataFrame: (12, 19)
# Skipped file Mecklenburg Vorpommern Deu.xlsx: An error occurred: argument of type 'float' is not iterable

# %%
import pandas as pd
from openpyxl import load_workbook
import os
from zipfile import BadZipFile
import re

# Updated category mapping based on new sectors
category_mapping = {
    'Agriculture': [
        'Agriculture, Forestry, and Fishing'
    ],
    'Industry': [
        'Mining and Quarrying, Manufacturing, Electricity, Gas, Steam, Air Conditioning and Water Supply, Sewerage, Waste Management, and Remediation Activities',
        'Construction'
    ],
    'Services': [
        'Wholesale and Retail Trade, Repair of Motor Vehicles and Motorcycles, Transportation and Storage, Accommodation, and Food Service Activities',
        'Information and Communication',
        'Financial and Insurance Activities',
        'Real Estate Activities',
        'Professional, Scientific, and Technical Activities, Administrative, and Support Service Activities',
        'Public Administration and Defence, Compulsory Social Security, Education, Human Health, and Social Work Activities',
        'Arts, Entertainment, Recreation, Other Service Activities, Activities of Households as Employers, Undifferentiated Goods and Services Producing Activities of Households for Own Use, Activities of Extraterritorial Organisations and Bodies'
    ]
}

# Function to classify sectors
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    # Use regex to match "GRC" or "Grc" as a standalone term in the filename
    if re.search(r'\b[Gg][Rr][Cc]\b', filename) and filename.endswith('.xlsx'):
        input_file_path = os.path.join(input_directory, filename)

        try:
            # Read the Excel file without skipping any rows
            df = pd.read_excel(input_file_path, engine='openpyxl', header=None)

            # Inspect the shape of the dataframe to understand its structure
            print(f"File: {filename} - Shape of DataFrame: {df.shape}")

            # Ensure we only select the first two columns starting from row 1 (row 2 in the file)
            df = df.iloc[1:, [0, 1]]  # Select the first two columns (Sector and Units), skipping the first row

            # Rename columns to 'Sector' and 'Units' for easier access
            df.columns = ['Sector', 'Units']

            # Convert the Units column to numeric, coerce errors to NaN
            df['Units'] = pd.to_numeric(df['Units'], errors='coerce')

            # Initialize a dictionary for aggregating GDP by category
            aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

            # Process each row
            for _, row in df.iterrows():
                description = row['Sector']
                gdp = row['Units']
                category = classify_sector(description)

                # If a category was found and GDP is not NaN, add the GDP to the respective category
                if category and not pd.isna(gdp):
                    aggregation[category] += gdp

            # Prepare the final DataFrame
            final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP Data'])

            # Calculate the total GDP
            total_gdp = final_df['Aggregated GDP Data'].sum()

            # Create a DataFrame for the total row
            total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP Data': [total_gdp]})

            # Concatenate the total row to the final DataFrame
            final_df = pd.concat([final_df, total_row], ignore_index=True)

            # Calculate the proportion of total GDP for each category
            final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP Data'] / total_gdp) * 100

            # Load the existing workbook to check for the existing sheet
            workbook = load_workbook(input_file_path)

            # Check if the sheet already exists
            if 'Aggregated GDP' in workbook.sheetnames:
                # Remove the existing sheet
                del workbook['Aggregated GDP']

            # Write the results to a new tab in the original Excel file
            with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                final_df.to_excel(writer, sheet_name='Aggregated GDP Data', index=False)

            print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
        except BadZipFile:
            print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
        except Exception as e:
            print(f"Skipped file {filename}: An error occurred: {e}")
# Out:
# File: Thessalias Grc.xlsx - Shape of DataFrame: (12, 19)
# Aggregation complete for Thessalias Grc.xlsx and saved to a new tab in the Excel file.
# File: Peloponnisoy Grc.xlsx - Shape of DataFrame: (12, 19)
# Aggregation complete for Peloponnisoy Grc.xlsx and saved to a new tab in the Excel file.
# File: Western Macedonia GRC.xlsx - Shape of DataFrame: (13, 19)
# Aggregation complete for Western Macedonia GRC.xlsx and saved to a new tab in the Excel file.
# File: Southern Aegean GRC.xlsx - Shape of DataFrame: (12, 19)
# Aggregation complete for Southern Aegean GRC.xlsx and saved to a new tab in the Excel file.
# File: Stereas Elladas Grc.xlsx - Shape of DataFrame: (12, 19)
# Aggregation complete for Stereas Elladas Grc.xlsx and saved to a new tab in the Excel file.
# File: Aegean Islands, Crete GRC.xlsx - Shape of DataFrame: (12, 19)
# Aggregation complete for Aegean Islands, Crete GRC.xlsx and saved to a new tab in the Excel file.
# File: Attica GRC.xlsx - Shape of DataFrame: (12, 19)
# Aggregation complete for Attica GRC.xlsx and saved to a new tab in the Excel file.
# File: Eastern Macedonia, Thrace GRC.xlsx - Shape of DataFrame: (12, 19)
# Aggregation complete for Eastern Macedonia, Thrace GRC.xlsx and saved to a new tab in the Excel file.
# File: Northern Greece GRC.xlsx - Shape of DataFrame: (12, 19)
# Aggregation complete for Northern Greece GRC.xlsx and saved to a new tab in the Excel file.
# File: Ionian Islands GRC.xlsx - Shape of DataFrame: (12, 19)
# Aggregation complete for Ionian Islands GRC.xlsx and saved to a new tab in the Excel file.
# File: Epirus GRC.xlsx - Shape of DataFrame: (12, 19)
# Aggregation complete for Epirus GRC.xlsx and saved to a new tab in the Excel file.
# File: Western Greece GRC.xlsx - Shape of DataFrame: (12, 19)
# Aggregation complete for Western Greece GRC.xlsx and saved to a new tab in the Excel file.
# File: Crete GRC.xlsx - Shape of DataFrame: (12, 19)
# Aggregation complete for Crete GRC.xlsx and saved to a new tab in the Excel file.
# File: Central Macedonia GRC.xlsx - Shape of DataFrame: (11, 19)
# Aggregation complete for Central Macedonia GRC.xlsx and saved to a new tab in the Excel file.
# File: Central Greece GRC .xlsx - Shape of DataFrame: (12, 18)
# Aggregation complete for Central Greece GRC .xlsx and saved to a new tab in the Excel file.

# %%
import pandas as pd
from openpyxl import load_workbook
import os
from zipfile import BadZipFile
import re

# CANADA SECTORS MAPPING
category_mapping = {
    'Agriculture': [
        'Agriculture, forestry, fishing and hunting'
    ],
    'Industry': [
        'Manufacturing',
        'Construction',
        'Utilities',
        'Mining, quarrying, and oil and gas extraction'
    ],
    'Services': [
        'Real estate and rental and leasing',
        'Public administration',
        'Health care and social assistance',
        'Retail trade',
        'Educational services',
        'Finance and insurance',
        'Transportation and warehousing',
        'Wholesale trade',
        'Professional, scientific and technical services',
        'Information and cultural industries',
        'Administrative and support, waste management and remediation services',
        'Other services (except public administration)',
        'Accommodation and food services',
        'Arts, entertainment and recreation',
        'Management of companies and enterprises'
    ]
}

# Function to classify sectors
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    if re.search(r'\bCAN\b', filename, re.IGNORECASE) and filename.endswith('.xlsx'):
        input_file_path = os.path.join(input_directory, filename)

        try:
            # Read the first two columns of the Excel file without headers
            df = pd.read_excel(input_file_path, engine='openpyxl', header=None, usecols=[0, 1])

            # Rename columns for clarity
            df.columns = ['Sector', 'GDP']

            # Convert the GDP column to numeric, coercing errors to NaN
            df['GDP'] = pd.to_numeric(df['GDP'], errors='coerce')

            # Initialize a dictionary for aggregating GDP by category
            aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

            # Process each row
            for _, row in df.iterrows():
                description = row['Sector']
                gdp = row['GDP']
                category = classify_sector(description)

                # If a category was found and GDP is not NaN, add the GDP to the respective category
                if category and not pd.isna(gdp):
                    aggregation[category] += gdp

            # Prepare the final DataFrame
            final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

            # Calculate the total GDP
            total_gdp = final_df['Aggregated GDP'].sum()

            # Create a DataFrame for the total row
            total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

            # Concatenate the total row to the final DataFrame
            final_df = pd.concat([final_df, total_row], ignore_index=True)

            # Calculate the proportion of total GDP for each category
            final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

            # Load the existing workbook to check for the existing sheet
            workbook = load_workbook(input_file_path)

            # Check if the sheet already exists
            if 'Aggregated Data' in workbook.sheetnames:
                del workbook['Aggregated Data']

            # Write the results to a new tab in the original Excel file
            with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                final_df.to_excel(writer, sheet_name='Aggregated Data', index=False)

            print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")

        except BadZipFile:
            print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
        except Exception as e:
            print(f"Skipped file {filename}: An error occurred: {e}")
# Out:
# Aggregation complete for Southeast Sud Est CAN.xlsx and saved to a new tab in the Excel file.
# Skipped file Northwest Territories Terri CAN.xlsx: An error occurred: argument of type 'numpy.float64' is not iterable
# Skipped file Can Tur.xlsx: An error occurred: Sheet 'Aggregated Data' already exists and if_sheet_exists is set to 'error'.
# Skipped file Ontario CAN.xlsx: An error occurred: argument of type 'float' is not iterable
# Aggregation complete for New Brunswick CAN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Nova Scotia CAN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Quebec CAN.xlsx and saved to a new tab in the Excel file.
# Skipped file Yukon CAN.xlsx: An error occurred: argument of type 'float' is not iterable
# Skipped file Alberta CAN.xlsx: An error occurred: argument of type 'numpy.float64' is not iterable
# Aggregation complete for British Columbia CAN.xlsx and saved to a new tab in the Excel file.
# Skipped file Sakatchewan CAN.xlsx: An error occurred: argument of type 'numpy.float64' is not iterable
# Skipped file Prince Edward Island CAN.xlsx: An error occurred: argument of type 'numpy.float64' is not iterable
# Skipped file Nunavut CAN.xlsx: An error occurred: argument of type 'numpy.float64' is not iterable
# Aggregation complete for Manitoba CAN.xlsx and saved to a new tab in the Excel file.

# %%
import pandas as pd
from openpyxl import load_workbook
import os
from zipfile import BadZipFile  # Import the error class
import re  # Import the regex module

# CHILE SECTORS MAPPING
category_mapping = {
    'Agriculture': [
        'Agriculture/livestock and forestry',
        'Fishery'
    ],
    'Industry': [
        'Mining',
        'Manufacturing industry',
        'Electricity, gas, water and waste management',
        'Construction'
    ],
    'Services': [
        'Wholesale and retail trade',
        'Hotels and restaurants',
        'Transport, information and communications',
        'Financial and business services',
        'Dwelling services and real estate',
        'Personal services',
        'Public administration'
    ]
}

# Function to classify sectors
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None  # Return None if no category is matched

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    # Use regex to match "Chl" or "CHL" as a standalone term in the filename
    if re.search(r'\b[Cc][Hh][Ll]\b', filename) and filename.endswith('.xlsx'):
        input_file_path = os.path.join(input_directory, filename)

        try:
            # Try to read the Excel file
            df = pd.read_excel(input_file_path, engine='openpyxl')

            # Ensure the DataFrame contains the expected columns
            if df.columns[0] == 'Sector' and df.columns[1] == 'GDP':
                # Convert the GDP column to numeric, coerce errors to NaN
                df['GDP'] = pd.to_numeric(df['GDP'], errors='coerce')

                # Initialize a dictionary for aggregating GDP by category
                aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

                # Process each row
                for _, row in df.iterrows():
                    description = row['Sector']
                    gdp = row['GDP']
                    category = classify_sector(description)

                    # If a category was found and GDP is not NaN, add the GDP to the respective category
                    if category and not pd.isna(gdp):
                        aggregation[category] += gdp

                # Prepare the final DataFrame
                final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

                # Calculate the total GDP
                total_gdp = final_df['Aggregated GDP'].sum()

                # Create a DataFrame for the total row
                total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

                # Concatenate the total row to the final DataFrame
                final_df = pd.concat([final_df, total_row], ignore_index=True)

                # Calculate the proportion of total GDP for each category
                final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

                # Load the existing workbook to check for the existing sheet
                workbook = load_workbook(input_file_path)

                # Check if the sheet already exists
                if 'Aggregated GDP' in workbook.sheetnames:
                    # Remove the existing sheet
                    del workbook['Aggregated GDP']

                # Write the results to a new tab in the original Excel file
                with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                    final_df.to_excel(writer, sheet_name='Aggregated Data', index=False)

                print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
            else:
                print(f"Error: The required columns 'Sector' and 'GDP' are not present in the file {filename}.")

        except BadZipFile:
            print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
        except Exception as e:
            print(f"Skipped file {filename}: An error occurred: {e}")
# Out:
# Aggregation complete for Provincia De Antofagasta Chl.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Provincia De Parinacota Chl.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Atacama CHL.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Metropolitan Region CHL.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Maule CHL.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Magallanes and the Chilean Antarctic CHL.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Libertador General Bernardo O Higgins CHL.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Coquimbo CHL.xlsx and saved to a new tab in the Excel file.

# %%
import pandas as pd
from openpyxl import load_workbook
import os
from zipfile import BadZipFile
import re

# MEXICO SECTORS MAPPING
category_mapping = {
    'Agriculture': [
        'Agriculture, Animal Husbandry and Exploitation, Forestry, Fishing and Hunting'
    ],
    'Industry': [
        'Mining',
        'Generation, Transmission and Distribution of Electricity, Water and Gas Pipeline to the Consumer',
        'Building',
        'Manufacturing Industries'
    ],
    'Services': [
        'Wholesale Trade',
        'Retail Trade',
        'Transportation and Storage',
        'Mass Media Information',
        'Financial and Insurance Services',
        'Real Estate and Rental Services of Furniture and Intangible Assets',
        'Services Professionals, Scientists and Technicals',
        'Support Services to Business and Waste Management and Waste and Remediation Services',
        'Educational Services',
        'Health and Social Assistance Services',
        'Leisure and Cultural Services, Sports, and other Recreational Services',
        'Temporary Accommodation and Food Preparation and Drinks',
        'Other Services except Government Activities'
    ]
}

# Function to classify sectors
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None  # Return None if no category is matched

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    # Use regex to match "Mex" or "MEX" in the filename
    if re.search(r'\b[Mm][Ee][Xx]\b', filename) and filename.endswith('.xlsx'):
        input_file_path = os.path.join(input_directory, filename)

        try:
            # Read the Excel file without headers and select only the first two columns
            df = pd.read_excel(input_file_path, engine='openpyxl', header=None, usecols=[0, 1])

            # Rename columns for consistency
            df.columns = ['Sector', 'GDP']

            # Convert the GDP column to numeric, coerce errors to NaN
            df['GDP'] = pd.to_numeric(df['GDP'], errors='coerce')

            # Initialize a dictionary for aggregating GDP by category
            aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

            # Process each row
            for _, row in df.iterrows():
                description = row['Sector']
                gdp = row['GDP']
                category = classify_sector(description)

                # If a category was found and GDP is not NaN, add the GDP to the respective category
                if category and not pd.isna(gdp):
                    aggregation[category] += gdp

            # Prepare the final DataFrame
            final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

            # Calculate the total GDP
            total_gdp = final_df['Aggregated GDP'].sum()

            # Create a DataFrame for the total row
            total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

            # Concatenate the total row to the final DataFrame
            final_df = pd.concat([final_df, total_row], ignore_index=True)

            # Calculate the proportion of total GDP for each category
            final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

            # Load the existing workbook to check for the existing sheet
            workbook = load_workbook(input_file_path)

            # Check if the sheet already exists
            if 'Aggregated GDP' in workbook.sheetnames:
                # Remove the existing sheet
                del workbook['Aggregated GDP']

            # Write the results to a new tab in the original Excel file
            with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                final_df.to_excel(writer, sheet_name='Aggregated Data', index=False)

            print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
        except BadZipFile:
            print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
        except Exception as e:
            print(f"Skipped file {filename}: An error occurred: {e}")
# Out:
# Aggregation complete for Heroica Villa Tezoatlan De Segura Y Luna Cuna De La Independencia De Oaxaca Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ojuelos De Jalisco Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Quintana Roo Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Aguascalientes Mex.xlsx and saved to a new tab in the Excel file.
# Skipped file Guanajuato Mex.xlsx: An error occurred: argument of type 'float' is not iterable
# Aggregation complete for Chihuahua Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Campeche Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Queretaro Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tlaxcala Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Zacatecas Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Guerrero Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Morelos Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tabasco Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hidalgo Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Durango Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Puebla Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for San Luis Potosi Mex.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Colima Mex.xlsx and saved to a new tab in the Excel file.

# %%
import pandas as pd
from openpyxl import load_workbook
import os

# GBR SECTORS MAPPING
category_mapping = {
    'Agriculture': [
        'Agriculture, forestry and fishing'
    ],
    'Industry': [
        'Production sector',
    ],
    'Services': [
        'Services sector',
    ]
}

# Function to classify sectors
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None  # Return None if no category is matched

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    if 'Gbr' in filename and filename.endswith('.xlsx'):  # Check for 'Gbr' in filename
        input_file_path = os.path.join(input_directory, filename)

        # Read the Excel file
        df = pd.read_excel(input_file_path)

        # Ensure the DataFrame contains the expected columns 'description' and '2021'
        if 'description' in df.columns and '2021' in df.columns:
            # Convert the '2021' column to numeric, coerce errors to NaN
            df['2021'] = pd.to_numeric(df['2021'], errors='coerce')

            # Initialize a dictionary for aggregating GDP by category
            aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

            # Process each row
            for _, row in df.iterrows():
                description = row['description']
                gdp = row['2021']
                category = classify_sector(description)

                # If a category was found and GDP is not NaN, add the GDP to the respective category
                if category and not pd.isna(gdp):
                    aggregation[category] += gdp

            # Prepare the final DataFrame
            final_df = pd.DataFrame(list(aggregation.items()), columns=['description', '2021'])

            # Calculate the total GDP
            total_gdp = final_df['2021'].sum()

            # Create a DataFrame for the total row
            total_row = pd.DataFrame({'description': ['Total'], '2021': [total_gdp]})

            # Concatenate the total row to the final DataFrame
            final_df = pd.concat([final_df, total_row], ignore_index=True)

            # Calculate the proportion of total GDP for each category
            final_df['Proportion of Total GDP'] = (final_df['2021'] / total_gdp) * 100

            # Load the existing workbook to check for the existing sheets
            workbook = load_workbook(input_file_path)

            # Check if the "Aggregated GDP Final" sheet exists and remove it if found
            if 'Aggregated GDP Final' in workbook.sheetnames:
                del workbook['Aggregated GDP Final']

            # Write the results to a new tab in the original Excel file
            with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                final_df.to_excel(writer, sheet_name='Aggregated GDP', index=False)

            print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
        else:
            print(f"Error: The required columns 'description' and '2021' are not present in the file {filename}.")
# Out:
# Aggregation complete for North East Lincolnshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bath and North East Somerset Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Nottingham Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Leicester Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Plymouth Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for York Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rutland Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Blackpool Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Warrington Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Blackburn With Darwen Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Peterborough Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Darlington Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for East Riding Of Yorkshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Derby Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Torbay Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Medway Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Thurrock Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Telford and Wrekin Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Swindon Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Luton Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for West Berkshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Brighton and Hove Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Milton Keynes Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Central Bedfordshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Southampton Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bedford Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wiltshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Isle Of Wight Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cheshire East Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Liverpool Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Manchester Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cornwall Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cheshire West and Chester Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Shropshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sheffield Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sunderland Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dorset Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Birmingham Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Northumberland Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Coventry Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Walsall Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Barnsley Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Calderdale Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wirral Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sefton Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Solihull Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sandwell Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for South Tyneside Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for City Of London Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wakefield Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dudley Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wolverhampton Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Leeds Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Barnet Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ealing Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Croydon Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Brent Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bexley Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hammersmith and Fulham Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lambeth Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Haringey Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bromley Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Redbridge Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hackney Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Barking and Dagenham Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Enfield Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cumbria Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hounslow Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tower Hamlets Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Wandsworth Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cambridgeshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kingston Upon Thames Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for East Sussex Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Harrow Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Derbyshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Devon Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Essex Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kent Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hampshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Buckinghamshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Northamptonshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lincolnshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hertfordshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for North Yorkshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Nottinghamshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Surrey Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Oxfordshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lancashire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Norfolk Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Suffolk Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Somerset Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Belfast Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Warwickshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Staffordshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mid Ulster Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for West Sussex Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Westminster Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Derry City and Strabane Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Antrim and Newtownabbey Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Clackmannanshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Fermanagh and Omagh Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Causeway Coast and Glens Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Moray Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for East Ayrshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for East Renfrewshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Shetland Islands Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Falkirk Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Mid and East Antrim Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Stirling Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Dumfries and Galloway Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lisburn and Castlereagh Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for East Lothian Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Aberdeen City Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for City Of Edinburgh Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Argyll and Bute Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Scottish Borders Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for South Ayrshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for South Lanarkshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Angus Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Glasgow City Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for West Dunbartonshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for North Lanarkshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for West Lothian Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Conwy Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Worcestershire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Flintshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gwynedd Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Isle Of Anglesey Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Monmouthshire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Powys Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Southend On Sea Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Swansea Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bradford Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Neath Port Talbot Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kingston Upon Hull City Of Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Stoke On Trent Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Armagh City Banbridge and Craigavon Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bournemouth Christchurch and Poole Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Herefordshire County Of Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Newry Mourne and Down Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bristol City Of Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Vale Of Glamorgan Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lewisham Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gloucestershire Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ards and North Down Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hartlepool Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Portsmouth Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Orkney Islands Gbr.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Na H Eileanan Siar Gbr.xlsx and saved to a new tab in the Excel file.

# %%
import pandas as pd
from openpyxl import load_workbook
import os

# RUS SECTORS MAPPING
category_mapping = {
    'Agriculture': [
        'Agriculture, forestry and fishing'
    ],
    'Industry': [
        'Mining and quarrying',
        'Manufacturing',
        'Construction',
        'Electricity, gas, steam and air conditioning supply',
        'Water supply; sewerage, waste management and remediation activities'
    ],
    'Services': [
        'Transportation and storage',
        'Wholesale and retail trade; repair of motor vehicles and motorcycles',
        'Public administration and defence; compulsory social security',
        'Human health and social work activities',
        'Education',
        'Real estate activities',
        'Information and communication',
        'Administrative and support service activities',
        'Professional, scientific and technical activities',
        'Accommodation and food service activities',
        'Arts, entertainment and recreation',
        'Other service activities',
        'Financial and insurance activities',
        'Activities of households as employers'
    ]
}

# Function to classify sectors
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None  # Return None if no category is matched

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    if 'Rus' in filename and filename.endswith('.xlsx'):  # Check for 'Rus' in filename
        input_file_path = os.path.join(input_directory, filename)

        # Read the Excel file without headers (since data has no headers)
        df = pd.read_excel(input_file_path, header=None)

        # Initialize a dictionary for aggregating GDP by category
        aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

        # Process rows in pairs: odd rows are descriptions, even rows are GDP values
        for i in range(0, len(df) - 1, 2):  # Iterate over rows two at a time
            description = df.iloc[i, 0]  # Sector name (odd row)
            gdp = pd.to_numeric(df.iloc[i + 1, 0], errors='coerce')  # GDP value (even row)

            # Classify sector and aggregate GDP if classification and GDP value are valid
            category = classify_sector(description)
            if category and not pd.isna(gdp):
                aggregation[category] += gdp

        # Prepare the final DataFrame
        final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

        # Calculate the total GDP
        total_gdp = final_df['Aggregated GDP'].sum()

        # Create a DataFrame for the total row
        total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

        # Concatenate the total row to the final DataFrame
        final_df = pd.concat([final_df, total_row], ignore_index=True)

        # Calculate the proportion of total GDP for each category
        final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

        # Load the existing workbook to check for the existing sheet
        workbook = load_workbook(input_file_path)

        # Check if the sheet already exists
        if 'Aggregated GDP' in workbook.sheetnames:
            # Remove the existing sheet
            del workbook['Aggregated GDP']

        # Write the results to a new tab in the original Excel file
        with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
            final_df.to_excel(writer, sheet_name='Aggregated GDP', index=False)

        print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
# Out:
# Aggregation complete for Russell Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rush Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rusk Usa.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Vologda Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Khabarovsk Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for 55107_Rusk_WI_USA.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gorodskoi Okrug Belgorod Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gorodskoi Okrug Kirov Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kursk Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gorodskoi Okrug Irkutsk Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gorodskoi Okrug Kaluga Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Penza Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Magadan Urban District Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Pskov Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Oryol Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gorodskoi Okrug Omsk Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Krasnoyarsk Urban Okrug Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gorodskoi Okrug Orenburg Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Voskhod Moscow Oblast Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Krasnodar Municipality Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tomsk Municipal Region Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rostov On Don Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Novosibirsk Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kaliningrad Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Chelyabinsk Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Volgograd Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Astrakhan Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Nizhny Novgorod Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Murmansk Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Smolensk Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kemerovo Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kostroma Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bryansk Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Saratov Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lipetsk Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ardatovsky District Republic Of Mordovia Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tambov Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Samara Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kurgan Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Voronezh Rus.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Yaroslavl Rus.xlsx and saved to a new tab in the Excel file.

# %%
import pandas as pd
from openpyxl import load_workbook
import os
import re  # Import the regular expressions module

# GBR SECTORS MAPPING
category_mapping = {
    'Agriculture': [
        'Agriculture, forestry and fishing'
    ],
    'Industry': [
        'Mining and quarrying',
        'Manufacturing',
        'Electricity, gas, steam and air conditioning supply',
        'Water supply, sewerage, waste management and remediation activities',
        'Construction'
    ],
    'Services': [
        'Wholesale and retail trade services, repair of vehicles and motorcycles',
        'Transportation and storage',
        'Accommodation and food service activities',
        'Information and communication',
        'Financial and insurance activities',
        'Real estate activities',
        'Professional, scientific and technical activities',
        'Administrative and support service activities',
        'Public administration and defence',
        'Compulsory social security',
        'Education',
        'Human health and social work activities',
        'Arts, entertainment and recreation',
        'Repair of household goods and other services'
    ]
}

# Function to classify sectors
def classify_sector(description):
    # Ensure description is a string; if NaN, return an empty string
    description = str(description) if pd.notna(description) else ''

    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None  # Return None if no category is matched

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    # Check for 'Ita' or 'ITA' as standalone words using regex
    if re.search(r'\b[Ii]ta\b', filename) and filename.endswith('.xlsx'):
        input_file_path = os.path.join(input_directory, filename)

        # Read the Excel file without headers
        df = pd.read_excel(input_file_path, header=None)

        # Ensure the DataFrame has at least 2 columns
        if df.shape[1] >= 2:
            # Select only the first two columns for processing
            df = df.iloc[:, :2]  # Keep only the first two columns
            df.columns = ['description', '2021']  # Rename columns for clarity

            # Convert the '2021' column to numeric, coercing errors to NaN
            df['2021'] = pd.to_numeric(df['2021'], errors='coerce')

            # Initialize a dictionary for aggregating GDP by category
            aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

            # Process each row
            for _, row in df.iterrows():
                description = row['description']
                gdp = row['2021']
                category = classify_sector(description)

                # If a category was found and GDP is not NaN, add the GDP to the respective category
                if category and not pd.isna(gdp):
                    aggregation[category] += gdp

            # Prepare the final DataFrame
            final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

            # Calculate the total GDP
            total_gdp = final_df['Aggregated GDP'].sum()

            # Create a DataFrame for the total row
            total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

            # Concatenate the total row to the final DataFrame
            final_df = pd.concat([final_df, total_row], ignore_index=True)

            # Calculate the proportion of total GDP for each category
            final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

            # Load the existing workbook to check for the existing sheet
            workbook = load_workbook(input_file_path)

            # Check if the sheet already exists
            if 'Aggregated GDP' in workbook.sheetnames:
                # Remove the existing sheet
                del workbook['Aggregated GDP']

            # Write the results to a new tab in the original Excel file
            with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                final_df.to_excel(writer, sheet_name='Aggregated GDP ITA', index=False)

            print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
        else:
            print(f"Error: The file {filename} does not have enough columns.")
# Out:
# Aggregation complete for Piemonte Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Veneto Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Abruzzo Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Basilicata Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Friuli Venezia Giulia Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Emilia Romagna Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Calabria Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Campania Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Puglia Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Valle D'Aosta Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Umbria Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lazio Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Molise Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sicilia Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Liguria Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Marche Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lombardia Ita.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Toscana Ita.xlsx and saved to a new tab in the Excel file.

# %%
import pandas as pd
from openpyxl import load_workbook
import os
from zipfile import BadZipFile  # Import the error class

# IDN SECTORS MAPPING
category_mapping = {
    'Agriculture': [
        '1. Agriculture, Forestry and Fishery'
    ],
    'Industry': [
        '2. Mining and Quarrying',
        '3. Manufacturing',
        '4. Electricity and Gas Supply',
        '5. Water Supply, Sewerage, Waste Management and Remediation Activities',
        '6. Construction'
    ],
    'Services': [
        '7. Wholesale and Retail Trades, Repair of Motor Vehicles and Motorcycles',
        '8. Transport and Storage',
        '9. Accommodation and Food Service Activities',
        '10. Information and Communication',
        '11. Financial and Insurance Services',
        'a. Financial Intermediary Services',
        '12. Real Estate Activities',
        '13. Business Services',
        '14. Public Administration and Defence; Compulsory Social Security',
        '15. Education',
        '16. Human Health and Social Work Activities',
        '17. Other Services Activities'
    ]
}

# Function to classify sectors
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None  # Return None if no category is matched

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    if 'Idn' in filename and filename.endswith('.xlsx'):  # Filter for IDN files
        input_file_path = os.path.join(input_directory, filename)

        try:
            # Read the Excel file without headers, using column positions (first column for sectors, second for values)
            df = pd.read_excel(input_file_path, engine='openpyxl', header=None)

            # Check if the DataFrame has at least 2 columns (and ignore any extra columns)
            if df.shape[1] >= 2:
                # Restrict the DataFrame to the first two columns
                df = df.iloc[:, :2]  # Select only the first two columns
                df.columns = ['Description', 'GDP']  # Rename the columns

                # Convert the GDP column to numeric, coerce errors to NaN
                df['GDP'] = pd.to_numeric(df['GDP'], errors='coerce')

                # Initialize a dictionary for aggregating GDP by category
                aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

                # Process each row
                for _, row in df.iterrows():
                    description = row['Description']
                    gdp = row['GDP']
                    category = classify_sector(description)

                    # If a category was found and GDP is not NaN, add the GDP to the respective category
                    if category and not pd.isna(gdp):
                        aggregation[category] += gdp

                # Prepare the final DataFrame
                final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

                # Calculate the total GDP
                total_gdp = final_df['Aggregated GDP'].sum()

                # Create a DataFrame for the total row
                total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

                # Concatenate the total row to the final DataFrame
                final_df = pd.concat([final_df, total_row], ignore_index=True)

                # Calculate the proportion of total GDP for each category
                final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

                # Load the existing workbook to check for the existing sheet
                workbook = load_workbook(input_file_path)

                # Check if the sheet already exists
                if 'Aggregated GDP' in workbook.sheetnames:
                    # Remove the existing sheet
                    del workbook['Aggregated GDP']

                # Write the results to a new tab in the original Excel file
                with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                    final_df.to_excel(writer, sheet_name='Aggregated Data', index=False)

                print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
            else:
                print(f"Error: The file {filename} does not have the required two columns.")

        except BadZipFile:
            print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
        except Exception as e:
            print(f"Skipped file {filename}: An error occurred: {e}")
# Out:
# Aggregation complete for Gorontalo Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bangka Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Maluku Barat Daya Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kota Jambi Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Buru Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Lampung Barat Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bengkulu Utara Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Aceh Jaya Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bangli Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kapuas Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bantaeng Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Berau Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Aceh Tenggara Idn.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sukamara Idn.xlsx and saved to a new tab in the Excel file.

# %%
import pandas as pd
from openpyxl import load_workbook
import os
from zipfile import BadZipFile  # Import the error class

# CHN SECTORS MAPPING
category_mapping = {
    'Agriculture': [
        'Processing of food from agricultural products'
    ],
    'Industry': [
        'Manufacture of special purpose machinery',
        'Manufacture of non-metallic mineral products',
        'Manufacture of communication equipment, computer and other electronic equipment',
        'Manufacture of chemical raw material and chemical products',
        'Manufacture and processing of non-ferrous metals',
        'Manufacture of general purpose machinery',
        'Manufacture of electrical machinery and equipment',
        'Production and supply of electric power and heat power',
        'Manufacture of metal products'
    ],
    'Services': [
        # Add services mappings here if needed, currently none of your sectors fall under services
    ]
}

# Additional keywords to classify as 'Industry'
industry_keywords = ['Manufacture', 'Processing', 'Production', 'Smelting']

# Function to classify sectors
def classify_sector(description):
    description_lower = description.lower()  # Convert description to lowercase for case-insensitive matching

    # Handle the exception for "Processing of food from agricultural products" first
    if 'processing of food from agricultural products' in description_lower:
        return 'Agriculture'

    # Check if the description contains any of the industry keywords
    for keyword in industry_keywords:
        if keyword.lower() in description_lower:
            return 'Industry'

    # Fall back to the defined category mapping
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword.lower() in description_lower:
                return category
    return None  # Return None if no category is matched

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    if 'CHN' in filename and filename.endswith('.xlsx'):  # Filter for CHN files
        input_file_path = os.path.join(input_directory, filename)

        try:
            # Read the Excel file without headers, using column positions (first column for sectors, second for values)
            df = pd.read_excel(input_file_path, engine='openpyxl', header=None)

            # Check if the DataFrame has at least 2 columns (and ignore any extra columns)
            if df.shape[1] >= 2:
                # Restrict the DataFrame to the first two columns
                df = df.iloc[:, :2]  # Select only the first two columns
                df.columns = ['Description', 'GDP']  # Rename the columns

                # Convert the GDP column to numeric, coerce errors to NaN
                df['GDP'] = pd.to_numeric(df['GDP'], errors='coerce')

                # Initialize a dictionary for aggregating GDP by category
                aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

                # Process each row
                for _, row in df.iterrows():
                    description = row['Description']
                    gdp = row['GDP']
                    category = classify_sector(description)

                    # If a category was found and GDP is not NaN, add the GDP to the respective category
                    if category and not pd.isna(gdp):
                        aggregation[category] += gdp

                # Prepare the final DataFrame
                final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

                # Calculate the total GDP
                total_gdp = final_df['Aggregated GDP'].sum()

                # Create a DataFrame for the total row
                total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

                # Concatenate the total row to the final DataFrame
                final_df = pd.concat([final_df, total_row], ignore_index=True)

                # Calculate the proportion of total GDP for each category
                final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

                # Load the existing workbook to check for the existing sheet
                workbook = load_workbook(input_file_path)

                # Check if the sheet already exists
                if 'Aggregated GDP' in workbook.sheetnames:
                    # Remove the existing sheet
                    del workbook['Aggregated GDP']

                # Write the results to a new tab in the original Excel file
                with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                    final_df.to_excel(writer, sheet_name='Aggregated Data Final', index=False)

                print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
            else:
                print(f"Error: The file {filename} does not have the required two columns.")

        except BadZipFile:
            print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
        except Exception as e:
            print(f"Skipped file {filename}: An error occurred: {e}")
# Out:
# Aggregation complete for Jiangxi CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gansu CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Guizhou CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hebei CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Guangdong CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hubei CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hunan CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jiangsu CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Inner Mongolia CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Shaanxi CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jilin CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tibet CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sichuan CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Shanxi CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Zhejiang CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Qinghai CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Ningxia CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Yunnan CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Fujian CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Chongqing CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Liaoning CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Anhui CHN.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Shanghai CHN.xlsx and saved to a new tab in the Excel file.

# %%
import pandas as pd
from openpyxl import load_workbook
import os
from zipfile import BadZipFile  # Import the error class

# IND SECTOR MAPPINGS
category_mapping = {
    'Agriculture': [
        'Crops',
        'Livestock',
        'Forestry & logging',
        'Fishing and aquaculture'
    ],
    'Industry': [
        'Mining & quarrying',
        'Manufacturing',
        'Electricity, gas, water supply & other utility services',
        'Construction'
    ],
    'Services': [
        'Trade, repair, hotels and restaurants',
        'Trade & repair services',
        'Hotels & restaurants',
        'Transport, storage, communication & services related to broadcasting',
        'Railways',
        'Road transport',
        'Water transport',
        'Air transport',
        'Services incidental to transport',
        'Storage',
        'Communication & services related to broadcasting',
        'Financial services',
        'Real estate, ownership of dwelling & professional services',
        'Public administration & defence',
        'Other services'
    ]
}

# Function to classify sectors
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            # Use exact match to avoid partial matches
            if keyword in description.split(', '):
                return category
    return None  # Return None if no category is matched

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    if 'IND' in filename and filename.endswith('.xlsx'):
        input_file_path = os.path.join(input_directory, filename)

        try:
            # Try to read the Excel file
            df = pd.read_excel(input_file_path, engine='openpyxl', header=None)

            # Extract sector names from column 2 starting from row 5
            sector_names = df.iloc[4:, 1].tolist()  # Column 2, row index 4 onwards
            # Extract values from column 3 starting from row 5
            values = pd.to_numeric(df.iloc[4:, 2], errors='coerce')  # Column 3, row index 4 onwards

            # Initialize a dictionary for aggregating GDP by category
            aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

            # Process each row
            for description, gdp in zip(sector_names, values):
                category = classify_sector(description)

                # If a category was found and GDP is not NaN, add the GDP to the respective category
                if category and not pd.isna(gdp):
                    aggregation[category] += gdp

            # Prepare the final DataFrame
            final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

            # Calculate the total GDP
            total_gdp = final_df['Aggregated GDP'].sum()

            # Create a DataFrame for the total row
            total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

            # Concatenate the total row to the final DataFrame
            final_df = pd.concat([final_df, total_row], ignore_index=True)

            # Calculate the proportion of total GDP for each category
            final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

            # Load the existing workbook
            workbook = load_workbook(input_file_path)

            # Check if the sheet already exists and remove it
            if 'Aggregated Data' in workbook.sheetnames:
                del workbook['Aggregated Data']

            # Write the results to a new tab in the original Excel file
            with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                final_df.to_excel(writer, sheet_name='Aggregated Data Updated', index=False)

            print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")

        except BadZipFile:
            print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
        except Exception as e:
            print(f"Skipped file {filename}: An error occurred: {e}")
# Out:
# Skipped file Andhra Pradesh IND.xlsx: An error occurred: 'float' object has no attribute 'split'
# Aggregation complete for Tamil Nadu IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Delhi IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Andaman & Nicobar Islands IND.xlsx and saved to a new tab in the Excel file.
# Skipped file Meghalaya IND.xlsx: An error occurred: 'float' object has no attribute 'split'
# Aggregation complete for Punjab IND.xlsx and saved to a new tab in the Excel file.
# Skipped file Mizoram IND.xlsx: An error occurred: 'float' object has no attribute 'split'
# Aggregation complete for Odisha IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Nagaland IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Rajasthan IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Puducherry IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Sikkim IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Arunachal Pradesh IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Telangana IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Goa IND.xlsx and saved to a new tab in the Excel file.
# Skipped file Tripura IND.xlsx: An error occurred: 'float' object has no attribute 'split'
# Aggregation complete for Chandigarh IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Haryana IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Bihar IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Assam IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jharkhand IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Jammu & Kashmir IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Gujarat IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for West Bengal IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Karnataka IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kerala IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Uttar Pradesh IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Uttarakhand IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Himachal Pradesh IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Maharashtra IND.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Manipur IND.xlsx and saved to a new tab in the Excel file.
# Skipped file Chhattisgarh IND.xlsx: An error occurred: 'float' object has no attribute 'split'
# Skipped file Madhya Pradesh IND.xlsx: An error occurred: 'float' object has no attribute 'split'

# %%
import pandas as pd
from openpyxl import load_workbook
import os
from zipfile import BadZipFile  # Import the error class

# TUR Sector Mappings
category_mapping = {
    'Agriculture': [
        'Agriculture, forestry and fishing',
    ],
    'Industry': [
        'Industry',
        'Manufacturing',
        'Construction',
    ],
    'Services': [
        'Services',
        'Information and communication',
        'Financial and insurance activities',
        'Real estate activities',
        'Professional, administrative and support service activities',
        'Public administration, education, human health and social work activities',
        'Other service activities'
    ]
}

# Function to classify sectors
def classify_sector(description):
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in description:
                return category
    return None  # Return None if no category is matched

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    if 'Tur' in filename and filename.endswith('.xlsx'):  # Updated to filter for 'Tur'
        input_file_path = os.path.join(input_directory, filename)

        try:
            # Try to read the Excel file without headers
            df = pd.read_excel(input_file_path, header=None, engine='openpyxl')

            # Ensure the DataFrame has enough rows and columns
            if df.shape[0] > 1 and df.shape[1] > 1:
                # Extract descriptions and GDP values from the DataFrame
                descriptions = df.iloc[1:, 0]  # Sector names (Column 1)
                gdp_values = pd.to_numeric(df.iloc[1:, 1], errors='coerce')  # Associated values (Column 2)

                # Initialize a dictionary for aggregating GDP by category
                aggregation = {'Agriculture': 0, 'Industry': 0, 'Services': 0}

                # Process each row
                for description, gdp in zip(descriptions, gdp_values):
                    category = classify_sector(description)

                    # If a category was found and GDP is not NaN, add the GDP to the respective category
                    if category and not pd.isna(gdp):
                        aggregation[category] += gdp

                # Prepare the final DataFrame
                final_df = pd.DataFrame(list(aggregation.items()), columns=['Category', 'Aggregated GDP'])

                # Calculate the total GDP
                total_gdp = final_df['Aggregated GDP'].sum()

                # Create a DataFrame for the total row
                total_row = pd.DataFrame({'Category': ['Total'], 'Aggregated GDP': [total_gdp]})

                # Concatenate the total row to the final DataFrame
                final_df = pd.concat([final_df, total_row], ignore_index=True)

                # Calculate the proportion of total GDP for each category
                final_df['Proportion of Total GDP'] = (final_df['Aggregated GDP'] / total_gdp) * 100

                # Load the existing workbook to check for the existing sheet
                workbook = load_workbook(input_file_path)

                # Check if the sheet already exists
                if 'Aggregated GDP' in workbook.sheetnames:
                    # Remove the existing sheet
                    del workbook['Aggregated GDP']

                # Write the results to a new tab in the original Excel file
                with pd.ExcelWriter(input_file_path, engine='openpyxl', mode='a') as writer:
                    final_df.to_excel(writer, sheet_name='Aggregated Data', index=False)

                print(f"Aggregation complete for {filename} and saved to a new tab in the Excel file.")
            else:
                print(f"Error: The required structure is not present in the file {filename}.")

        except BadZipFile:
            print(f"Skipped file {filename}: File is not a valid zip (Excel) file.")
        except Exception as e:
            print(f"Skipped file {filename}: An error occurred: {e}")
# Out:
# Aggregation complete for Zonguldak Merkez Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kastamonu Merkez Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Aydincik Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Karesi Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Hayrat Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Manyas Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kirikhan Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Antakya Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Kocarli Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Izmit Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Abana Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Agli Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Alanya Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Urla Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Cankaya Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Emirdag Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Aglasun Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Tonya Tur.xlsx and saved to a new tab in the Excel file.
# Aggregation complete for Can Tur.xlsx and saved to a new tab in the Excel file.
# Skipped file Turner Usa.xlsx: An error occurred: Sheet 'Aggregated Data' already exists and if_sheet_exists is set to 'error'.
