# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
from openpyxl import load_workbook

# Path to the input directory
input_directory = '/content/drive/MyDrive/Summer work/Sources for GDP Datasets'

# Hyperlink details
hyperlink_url = "https://apps.bea.gov/itable/?ReqID=70&step=1&acrdn=5#"
link_text = "Source"
header_text = "Source for Data"

# Iterate through files in the input directory
for filename in os.listdir(input_directory):
    if 'Usa' in filename and filename.endswith('.xlsx'):
        file_path = os.path.join(input_directory, filename)

        try:
            # Load the workbook and select the first sheet
            workbook = load_workbook(file_path)
            sheet = workbook.active  # Select the first sheet (active sheet)

            # Insert header text into the first row (I1)
            sheet.cell(row=1, column=9).value = header_text

            # Insert the hyperlink into cell I2 (Column 9, Row 2)
            cell = sheet.cell(row=2, column=9)
            cell.hyperlink = hyperlink_url
            cell.value = link_text
            cell.style = "Hyperlink"  # Apply hyperlink style

            # Save the workbook
            workbook.save(file_path)

            print(f"Hyperlink added to {filename}")
        except Exception as e:
            print(f"Error processing {filename}: {e}")
# Out:
# Hyperlink added to Tishomingo Usa.xlsx
# Hyperlink added to Kewaunee Usa.xlsx
# Hyperlink added to Mccracken Usa.xlsx
# Hyperlink added to Haralson Usa.xlsx
# Hyperlink added to Mohave Usa.xlsx
# Hyperlink added to Haines Usa.xlsx
# Hyperlink added to Garland Usa.xlsx
# Hyperlink added to Neosho Usa.xlsx
# Hyperlink added to Rockwall Usa.xlsx
# Hyperlink added to Tuolumne Usa.xlsx
# Hyperlink added to Mahnomen Usa.xlsx
# Hyperlink added to Davison Usa.xlsx
# Hyperlink added to San Lorenzo Usa.xlsx
# Hyperlink added to Muskegon Usa.xlsx
# Hyperlink added to Cross Usa.xlsx
# Hyperlink added to Olmsted Usa.xlsx
# Hyperlink added to Dallam Usa.xlsx
# Hyperlink added to Tehama Usa.xlsx
# Hyperlink added to Ripley Usa.xlsx
# Hyperlink added to Blanco Usa.xlsx
# Hyperlink added to Kendall Usa.xlsx
# Hyperlink added to Moultrie Usa.xlsx
# Hyperlink added to Mckinley Usa.xlsx
# Hyperlink added to Bastrop Usa.xlsx
# Hyperlink added to Florida Usa.xlsx
# Hyperlink added to Bartholomew Usa.xlsx
# ...
